# %%
import pandas as pd

# %%
# !pipenv install xlrd

# %%
df = pd.read_excel('C:\\python_env\\flask ml app\\template\\template_Sales_Agreement_v1.xlsx', skiprows=2, engine='openpyxl',header=None, usecols=[0, 1])
df.head()
# Out:
#                      0           1
# 0      Expiration Term    End Date
# 1                 term   extension
# 2  terms and condition        term
# 3    terms & condition  full force
# 4           full force       renew

# %%
df0 = pd.read_excel('09_10_2021_17_20_04__template_Sales_Agreement_v1.xlsx', engine='openpyxl', header=None,usecols=[0,1] )
df_1 = df0[:2]
df_1
# Out:
#           0                1
# 0   Version                1
# 1  Category  Sales Agreement

# %%
list(df_1.loc[0])
# Out:
# ['Version', 1]

# %%
df.columns
# Out:
# Index(['Expiration Term', 'End Date', 'scope of services',
#        'Guaranteed Productivity', 'Innovation fund', 'Volume Adjustments',
#        'Foreign Exchange and Adjusment', 'Cost Of Living Adjustments',
#        'Gain Share above Guraanted Productivity', 'Service Commencement level',
#        'Service efficiency Service level',
#        'Service Request acceptance and rejection Service level'],
#       dtype='object')

# %%
for i in df.columns:
    print(i, df[i])
# Out:
# Expiration Term 0                   term
# 1    terms and condition
# 2      terms & condition
# 3             full force
# 4                    NaN
# 5                    NaN
# Name: Expiration Term, dtype: object
# End Date 0              extension
# 1                   term
# 2             full force
# 3                  renew
# 4              period of
# 5    terms and condition
# Name: End Date, dtype: object
# scope of services 0                         scope of services
# 1                    Client hereby appoints
# 2    Subject to the terms of this Agreement
# 3         APPOINTMENT AND SCOPE OF SERVICES
# 4                                       NaN
# 5                                       NaN
# Name: scope of services, dtype: object
# Guaranteed Productivity 0                 Guaranteed
# 1               productivity
# 2    Guaranteed Productivity
# 3                        fte
# 4                 reduce fte
# 5                        NaN
# ...

# %%
df['Expiration Term']
# Out:
# 0                   term
# 1    terms and condition
# 2      terms & condition
# 3             full force
# 4                    NaN
# 5                    NaN
# Name: Expiration Term, dtype: object

# %%
df.isnull().sum()
# Out:
# Expiration Term                                           2
# End Date                                                  0
# scope of services                                         2
# Guaranteed Productivity                                   1
# Innovation fund                                           3
# Volume Adjustments                                        3
# Foreign Exchange and Adjusment                            2
# Cost Of Living Adjustments                                1
# Gain Share above Guraanted Productivity                   1
# Service Commencement level                                4
# Service efficiency Service level                          4
# Service Request acceptance and rejection Service level    3
# dtype: int64

# %%
df1 = df.fillna(0)
df1
# Out:
#        Expiration Term             End Date  \
# 0                 term            extension
# 1  terms and condition                 term
# 2    terms & condition           full force
# 3           full force                renew
# 4                    0            period of
# 5                    0  terms and condition
#
#                         scope of services  Guaranteed Productivity  \
# 0                       scope of services               Guaranteed
# 1                  Client hereby appoints             productivity
# 2  Subject to the terms of this Agreement  Guaranteed Productivity
# 3       APPOINTMENT AND SCOPE OF SERVICES                      fte
# 4                                       0               reduce fte
# 5                                       0                        0
#
#    Innovation fund Volume Adjustments Foreign Exchange and Adjusment  \
# 0      Innovation             volume                        Foreign
# ...

# %%
df.head()
# Out:
#        Expiration Term    End Date                       scope of services  \
# 0                 term   extension                       scope of services
# 1  terms and condition        term                  Client hereby appoints
# 2    terms & condition  full force  Subject to the terms of this Agreement
# 3           full force       renew       APPOINTMENT AND SCOPE OF SERVICES
# 4                  NaN   period of                                     NaN
#
#    Guaranteed Productivity  Innovation fund Volume Adjustments  \
# 0               Guaranteed      Innovation             volume
# 1             productivity             fund         adjusments
# 2  Guaranteed Productivity  Innovation fund  Volume Adjustment
# 3                      fte              NaN                NaN
# 4               reduce fte              NaN                NaN
#
#   Foreign Exchange and Adjusment  Cost Of Living Adjustments  \
# 0                       Foreign                       Living
# ...
